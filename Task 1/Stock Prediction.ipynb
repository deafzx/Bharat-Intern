# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore') 
from sklearn.preprocessing import MinMaxScaler 
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional

# %%
df = pd.read_csv("NFLX.csv")
# fetching first 10 rows of dataset
df.head(10)
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 1  2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2  2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 3  2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 4  2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
# 5  2018-02-12  252.139999  259.149994  249.000000  257.950012  257.950012
# 6  2018-02-13  257.290009  261.410004  254.699997  258.269989  258.269989
# 7  2018-02-14  260.470001  269.880005  260.329987  266.000000  266.000000
# 8  2018-02-15  270.029999  280.500000  267.630005  280.269989  280.269989
# 9  2018-02-16  278.730011  281.959991  275.690002  278.519989  278.519989
#
#      Volume
# 0  11896100
# 1  12595800
# 2   8981500
# 3   9306700
# 4  16906900
# 5   8534900
# 6   6855200
# 7  10972000
# 8  10759700
# 9   8312400

# %%
df.tail()
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 1004  2022-01-31  401.970001  427.700012  398.200012  427.140015  427.140015
# 1005  2022-02-01  432.959991  458.480011  425.540009  457.130005  457.130005
# 1006  2022-02-02  448.250000  451.980011  426.480011  429.480011  429.480011
# 1007  2022-02-03  421.440002  429.260010  404.279999  405.600006  405.600006
# 1008  2022-02-04  407.309998  412.769989  396.640015  410.170013  410.170013
#
#         Volume
# 1004  20047500
# 1005  22542300
# 1006  14346000
# 1007   9905200
# 1008   7782400

# %%
df.shape
# Out:
# (1009, 7)

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1009.000000  1009.000000  1009.000000  1009.000000  1009.000000
# mean    419.059673   425.320703   412.374044   419.000733   419.000733
# std     108.537532   109.262960   107.555867   108.289999   108.289999
# min     233.919998   250.649994   231.229996   233.880005   233.880005
# 25%     331.489990   336.299988   326.000000   331.619995   331.619995
# 50%     377.769989   383.010010   370.880005   378.670013   378.670013
# 75%     509.130005   515.630005   502.529999   509.079987   509.079987
# max     692.349976   700.989990   686.090027   691.690002   691.690002
#
#              Volume
# count  1.009000e+03
# mean   7.570685e+06
# std    5.465535e+06
# min    1.144000e+06
# 25%    4.091900e+06
# 50%    5.934500e+06
# 75%    9.322400e+06
# max    5.890430e+07

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1009 entries, 0 to 1008
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1009 non-null   object
#  1   Open       1009 non-null   float64
#  2   High       1009 non-null   float64
#  3   Low        1009 non-null   float64
#  4   Close      1009 non-null   float64
#  5   Adj Close  1009 non-null   float64
#  6   Volume     1009 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 55.3+ KB

# %%
df.count()
# Out:
# Date         1009
# Open         1009
# High         1009
# Low          1009
# Close        1009
# Adj Close    1009
# Volume       1009
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df = df[['Date','Open','Close']] 

# converting object dtype of date column to datetime dtype

df['Date'] = pd.to_datetime(df['Date'].apply(lambda x: x.split()[0]))

# %%
df.set_index('Date',drop=True,inplace=True) 
df.head(10)
# Out:
#                   Open       Close
# Date
# 2018-02-05  262.000000  254.259995
# 2018-02-06  247.699997  265.720001
# 2018-02-07  266.579987  264.559998
# 2018-02-08  267.079987  250.100006
# 2018-02-09  253.850006  249.470001
# 2018-02-12  252.139999  257.950012
# 2018-02-13  257.290009  258.269989
# 2018-02-14  260.470001  266.000000
# 2018-02-15  270.029999  280.269989
# 2018-02-16  278.730011  278.519989

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'Open'}>,
#         <Axes: title={'center': 'Close'}>]], dtype=object)

# %%
fig, ax =plt.subplots(1,2,figsize=(20,7))
ax[0].plot(df['Open'],label='Open',color='blue')
ax[0].set_xlabel('Date',size=15)
ax[0].set_ylabel('Price',size=15)
ax[0].legend()

ax[1].plot(df['Close'],label='Close',color='green')
ax[1].set_xlabel('Date',size=15)
ax[1].set_ylabel('Price',size=15)
ax[1].legend()

fig.show()

# %%
MMS = MinMaxScaler()
df[df.columns] = MMS.fit_transform(df)
df.head(10)
# Out:
#                 Open     Close
# Date
# 2018-02-05  0.061253  0.044516
# 2018-02-06  0.030059  0.069548
# 2018-02-07  0.071243  0.067015
# 2018-02-08  0.072334  0.035430
# 2018-02-09  0.043474  0.034053
# 2018-02-12  0.039744  0.052576
# 2018-02-13  0.050978  0.053275
# 2018-02-14  0.057915  0.070160
# 2018-02-15  0.078769  0.101330
# 2018-02-16  0.097747  0.097508

# %%
df.tail(10)
# Out:
#                 Open     Close
# Date
# 2022-01-24  0.327182  0.334790
# 2022-01-25  0.316777  0.289509
# 2022-01-26  0.314879  0.274830
# 2022-01-27  0.323146  0.333807
# 2022-01-28  0.333399  0.328695
# 2022-01-31  0.366577  0.422140
# 2022-02-01  0.434178  0.487648
# 2022-02-02  0.467531  0.427251
# 2022-02-03  0.409048  0.375090
# 2022-02-04  0.378226  0.385072

# %%
training_size = round(len(df) * 0.75)

# %%
training_size
# Out:
# 757

# %%
train_data = df[:training_size]
test_data  = df[training_size:]

train_data.shape, test_data.shape
# Out:
# ((757, 2), (252, 2))

# %%
def create_sequence(dataset):
  sequences = []
  labels = []

  start_idx = 0

  for stop_idx in range(50,len(dataset)): # Selecting 50 rows at a time
    sequences.append(dataset.iloc[start_idx:stop_idx])
    labels.append(dataset.iloc[stop_idx])
    start_idx += 1
  return (np.array(sequences),np.array(labels))
train_seq, train_label = create_sequence(train_data) 
test_seq, test_label = create_sequence(test_data)
train_seq.shape, train_label.shape, test_seq.shape, test_label.shape
# Out:
# ((707, 50, 2), (707, 2), (202, 50, 2), (202, 2))

# %%
model = Sequential()
# importing Dense, Dropout, LSTM, Bidirectional from keras.layers 
model.add(LSTM(units=25, return_sequences=True, input_shape = (train_seq.shape[1], train_seq.shape[2])))

model.add(Dropout(0.1)) 
model.add(LSTM(units=25))

model.add(Dense(2))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50, 25)            2800
#
#  dropout (Dropout)           (None, 50, 25)            0
#
#  lstm_1 (LSTM)               (None, 25)                5100
#
#  dense (Dense)               (None, 2)                 52
#
# =================================================================
# Total params: 7952 (31.06 KB)
# Trainable params: 7952 (31.06 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(train_seq, train_label, epochs=100,validation_data=(test_seq, test_label), verbose=1)
# Out:
# Epoch 1/100
# 23/23 [==============================] - 7s 97ms/step - loss: 0.0477 - mean_absolute_error: 0.1627 - val_loss: 0.0226 - val_mean_absolute_error: 0.1147
# Epoch 2/100
# 23/23 [==============================] - 1s 35ms/step - loss: 0.0074 - mean_absolute_error: 0.0654 - val_loss: 0.0179 - val_mean_absolute_error: 0.1018
# Epoch 3/100
# 23/23 [==============================] - 1s 35ms/step - loss: 0.0039 - mean_absolute_error: 0.0478 - val_loss: 0.0115 - val_mean_absolute_error: 0.0794
# Epoch 4/100
# 23/23 [==============================] - 1s 40ms/step - loss: 0.0027 - mean_absolute_error: 0.0404 - val_loss: 0.0095 - val_mean_absolute_error: 0.0718
# Epoch 5/100
# 23/23 [==============================] - 1s 31ms/step - loss: 0.0026 - mean_absolute_error: 0.0397 - val_loss: 0.0090 - val_mean_absolute_error: 0.0688
# Epoch 6/100
# 23/23 [==============================] - 1s 36ms/step - loss: 0.0027 - mean_absolute_error: 0.0397 - val_loss: 0.0094 - val_mean_absolute_error: 0.0717
# Epoch 7/100
# 23/23 [==============================] - 1s 37ms/step - loss: 0.0026 - mean_absolute_error: 0.0387 - val_loss: 0.0088 - val_mean_absolute_error: 0.0681
# Epoch 8/100
# 23/23 [==============================] - 1s 35ms/step - loss: 0.0025 - mean_absolute_error: 0.0386 - val_loss: 0.0082 - val_mean_absolute_error: 0.0656
# Epoch 9/100
# 23/23 [==============================] - 1s 45ms/step - loss: 0.0026 - mean_absolute_error: 0.0393 - val_loss: 0.0080 - val_mean_absolute_error: 0.0646
# Epoch 10/100
# 23/23 [==============================] - 1s 41ms/step - loss: 0.0025 - mean_absolute_error: 0.0382 - val_loss: 0.0077 - val_mean_absolute_error: 0.0630
# Epoch 11/100
# 23/23 [==============================] - 1s 38ms/step - loss: 0.0024 - mean_absolute_error: 0.0377 - val_loss: 0.0075 - val_mean_absolute_error: 0.0618
# Epoch 12/100
# 23/23 [==============================] - 1s 38ms/step - loss: 0.0023 - mean_absolute_error: 0.0369 - val_loss: 0.0073 - val_mean_absolute_error: 0.0609
# Epoch 13/100
# 23/23 [==============================] - 1s 34ms/step - loss: 0.0023 - mean_absolute_error: 0.0366 - val_loss: 0.0071 - val_mean_absolute_error: 0.0599
# Epoch 14/100
# 23/23 [==============================] - 1s 42ms/step - loss: 0.0022 - mean_absolute_error: 0.0359 - val_loss: 0.0069 - val_mean_absolute_error: 0.0588
# Epoch 15/100
# 23/23 [==============================] - 1s 33ms/step - loss: 0.0023 - mean_absolute_error: 0.0359 - val_loss: 0.0071 - val_mean_absolute_error: 0.0594
# Epoch 16/100
# 23/23 [==============================] - 1s 36ms/step - loss: 0.0021 - mean_absolute_error: 0.0351 - val_loss: 0.0064 - val_mean_absolute_error: 0.0565
# Epoch 17/100
# 23/23 [==============================] - 1s 38ms/step - loss: 0.0021 - mean_absolute_error: 0.0353 - val_loss: 0.0064 - val_mean_absolute_error: 0.0568
# Epoch 18/100
# 23/23 [==============================] - 1s 43ms/step - loss: 0.0022 - mean_absolute_error: 0.0353 - val_loss: 0.0072 - val_mean_absolute_error: 0.0642
# Epoch 19/100
# 23/23 [==============================] - 1s 42ms/step - loss: 0.0022 - mean_absolute_error: 0.0356 - val_loss: 0.0059 - val_mean_absolute_error: 0.0533
# Epoch 20/100
# 23/23 [==============================] - 1s 40ms/step - loss: 0.0022 - mean_absolute_error: 0.0349 - val_loss: 0.0060 - val_mean_absolute_error: 0.0556
# Epoch 21/100
# 23/23 [==============================] - 1s 46ms/step - loss: 0.0020 - mean_absolute_error: 0.0344 - val_loss: 0.0057 - val_mean_absolute_error: 0.0542
# Epoch 22/100
# 23/23 [==============================] - 1s 48ms/step - loss: 0.0021 - mean_absolute_error: 0.0345 - val_loss: 0.0055 - val_mean_absolute_error: 0.0530
# Epoch 23/100
# 23/23 [==============================] - 1s 39ms/step - loss: 0.0020 - mean_absolute_error: 0.0340 - val_loss: 0.0054 - val_mean_absolute_error: 0.0523
# Epoch 24/100
# 23/23 [==============================] - 1s 35ms/step - loss: 0.0021 - mean_absolute_error: 0.0344 - val_loss: 0.0051 - val_mean_absolute_error: 0.0500
# Epoch 25/100
# 23/23 [==============================] - 1s 44ms/step - loss: 0.0021 - mean_absolute_error: 0.0346 - val_loss: 0.0052 - val_mean_absolute_error: 0.0510
# Epoch 26/100
# 23/23 [==============================] - 1s 45ms/step - loss: 0.0020 - mean_absolute_error: 0.0335 - val_loss: 0.0058 - val_mean_absolute_error: 0.0547
# Epoch 27/100
# 23/23 [==============================] - 1s 46ms/step - loss: 0.0020 - mean_absolute_error: 0.0340 - val_loss: 0.0052 - val_mean_absolute_error: 0.0514
# Epoch 28/100
# 23/23 [==============================] - 1s 54ms/step - loss: 0.0020 - mean_absolute_error: 0.0329 - val_loss: 0.0049 - val_mean_absolute_error: 0.0483
# Epoch 29/100
# 23/23 [==============================] - 1s 31ms/step - loss: 0.0018 - mean_absolute_error: 0.0320 - val_loss: 0.0049 - val_mean_absolute_error: 0.0496
# Epoch 30/100
# 23/23 [==============================] - 1s 33ms/step - loss: 0.0018 - mean_absolute_error: 0.0316 - val_loss: 0.0049 - val_mean_absolute_error: 0.0503
# Epoch 31/100
# 23/23 [==============================] - 1s 33ms/step - loss: 0.0018 - mean_absolute_error: 0.0321 - val_loss: 0.0045 - val_mean_absolute_error: 0.0478
# Epoch 32/100
# 23/23 [==============================] - 1s 37ms/step - loss: 0.0018 - mean_absolute_error: 0.0318 - val_loss: 0.0042 - val_mean_absolute_error: 0.0443
# Epoch 33/100
# 23/23 [==============================] - 1s 33ms/step - loss: 0.0018 - mean_absolute_error: 0.0319 - val_loss: 0.0044 - val_mean_absolute_error: 0.0460
# Epoch 34/100
# 23/23 [==============================] - 1s 31ms/step - loss: 0.0019 - mean_absolute_error: 0.0325 - val_loss: 0.0046 - val_mean_absolute_error: 0.0475
# Epoch 35/100
# 23/23 [==============================] - 1s 33ms/step - loss: 0.0018 - mean_absolute_error: 0.0317 - val_loss: 0.0040 - val_mean_absolute_error: 0.0433
# Epoch 36/100
# 23/23 [==============================] - 1s 37ms/step - loss: 0.0017 - mean_absolute_error: 0.0304 - val_loss: 0.0039 - val_mean_absolute_error: 0.0426
# Epoch 37/100
# 23/23 [==============================] - 1s 38ms/step - loss: 0.0017 - mean_absolute_error: 0.0302 - val_loss: 0.0039 - val_mean_absolute_error: 0.0429
# Epoch 38/100
# 23/23 [==============================] - 1s 29ms/step - loss: 0.0017 - mean_absolute_error: 0.0313 - val_loss: 0.0040 - val_mean_absolute_error: 0.0439
# Epoch 39/100
# 23/23 [==============================] - 1s 35ms/step - loss: 0.0016 - mean_absolute_error: 0.0296 - val_loss: 0.0037 - val_mean_absolute_error: 0.0415
# Epoch 40/100
# 23/23 [==============================] - 1s 29ms/step - loss: 0.0016 - mean_absolute_error: 0.0303 - val_loss: 0.0036 - val_mean_absolute_error: 0.0423
# Epoch 41/100
# 23/23 [==============================] - 1s 31ms/step - loss: 0.0016 - mean_absolute_error: 0.0303 - val_loss: 0.0041 - val_mean_absolute_error: 0.0446
# Epoch 42/100
# 23/23 [==============================] - 1s 31ms/step - loss: 0.0016 - mean_absolute_error: 0.0300 - val_loss: 0.0039 - val_mean_absolute_error: 0.0428
# Epoch 43/100
# 23/23 [==============================] - 1s 34ms/step - loss: 0.0016 - mean_absolute_error: 0.0297 - val_loss: 0.0037 - val_mean_absolute_error: 0.0416
# Epoch 44/100
# 23/23 [==============================] - 1s 31ms/step - loss: 0.0015 - mean_absolute_error: 0.0290 - val_loss: 0.0036 - val_mean_absolute_error: 0.0413
# Epoch 45/100
# 23/23 [==============================] - 1s 34ms/step - loss: 0.0015 - mean_absolute_error: 0.0289 - val_loss: 0.0034 - val_mean_absolute_error: 0.0403
# Epoch 46/100
# 23/23 [==============================] - 1s 29ms/step - loss: 0.0014 - mean_absolute_error: 0.0280 - val_loss: 0.0037 - val_mean_absolute_error: 0.0431
# Epoch 47/100
# 23/23 [==============================] - 1s 40ms/step - loss: 0.0015 - mean_absolute_error: 0.0288 - val_loss: 0.0036 - val_mean_absolute_error: 0.0406
# Epoch 48/100
# 23/23 [==============================] - 1s 35ms/step - loss: 0.0014 - mean_absolute_error: 0.0281 - val_loss: 0.0033 - val_mean_absolute_error: 0.0388
# Epoch 49/100
# 23/23 [==============================] - 1s 32ms/step - loss: 0.0014 - mean_absolute_error: 0.0279 - val_loss: 0.0046 - val_mean_absolute_error: 0.0505
# Epoch 50/100
# 23/23 [==============================] - 1s 30ms/step - loss: 0.0015 - mean_absolute_error: 0.0288 - val_loss: 0.0034 - val_mean_absolute_error: 0.0394
# Epoch 51/100
# 23/23 [==============================] - 1s 34ms/step - loss: 0.0014 - mean_absolute_error: 0.0275 - val_loss: 0.0030 - val_mean_absolute_error: 0.0368
# Epoch 52/100
# 23/23 [==============================] - 1s 32ms/step - loss: 0.0013 - mean_absolute_error: 0.0268 - val_loss: 0.0039 - val_mean_absolute_error: 0.0446
# Epoch 53/100
# 23/23 [==============================] - 1s 35ms/step - loss: 0.0013 - mean_absolute_error: 0.0266 - val_loss: 0.0035 - val_mean_absolute_error: 0.0404
# Epoch 54/100
# 23/23 [==============================] - 1s 32ms/step - loss: 0.0013 - mean_absolute_error: 0.0271 - val_loss: 0.0033 - val_mean_absolute_error: 0.0392
# Epoch 55/100
# 23/23 [==============================] - 1s 35ms/step - loss: 0.0014 - mean_absolute_error: 0.0280 - val_loss: 0.0034 - val_mean_absolute_error: 0.0402
# Epoch 56/100
# 23/23 [==============================] - 1s 36ms/step - loss: 0.0013 - mean_absolute_error: 0.0270 - val_loss: 0.0030 - val_mean_absolute_error: 0.0368
# Epoch 57/100
# 23/23 [==============================] - 1s 33ms/step - loss: 0.0013 - mean_absolute_error: 0.0262 - val_loss: 0.0037 - val_mean_absolute_error: 0.0428
# Epoch 58/100
# 23/23 [==============================] - 1s 38ms/step - loss: 0.0012 - mean_absolute_error: 0.0259 - val_loss: 0.0030 - val_mean_absolute_error: 0.0373
# Epoch 59/100
# 23/23 [==============================] - 1s 37ms/step - loss: 0.0012 - mean_absolute_error: 0.0264 - val_loss: 0.0040 - val_mean_absolute_error: 0.0460
# Epoch 60/100
# 23/23 [==============================] - 1s 36ms/step - loss: 0.0012 - mean_absolute_error: 0.0257 - val_loss: 0.0030 - val_mean_absolute_error: 0.0366
# Epoch 61/100
# 23/23 [==============================] - 1s 33ms/step - loss: 0.0012 - mean_absolute_error: 0.0255 - val_loss: 0.0044 - val_mean_absolute_error: 0.0488
# Epoch 62/100
# 23/23 [==============================] - 1s 36ms/step - loss: 0.0012 - mean_absolute_error: 0.0257 - val_loss: 0.0037 - val_mean_absolute_error: 0.0444
# Epoch 63/100
# 23/23 [==============================] - 1s 35ms/step - loss: 0.0013 - mean_absolute_error: 0.0277 - val_loss: 0.0029 - val_mean_absolute_error: 0.0365
# Epoch 64/100
# 23/23 [==============================] - 1s 35ms/step - loss: 0.0011 - mean_absolute_error: 0.0250 - val_loss: 0.0031 - val_mean_absolute_error: 0.0373
# Epoch 65/100
# 23/23 [==============================] - 1s 35ms/step - loss: 0.0012 - mean_absolute_error: 0.0263 - val_loss: 0.0033 - val_mean_absolute_error: 0.0422
# Epoch 66/100
# 23/23 [==============================] - 1s 33ms/step - loss: 0.0011 - mean_absolute_error: 0.0242 - val_loss: 0.0037 - val_mean_absolute_error: 0.0427
# Epoch 67/100
# 23/23 [==============================] - 1s 34ms/step - loss: 0.0011 - mean_absolute_error: 0.0249 - val_loss: 0.0025 - val_mean_absolute_error: 0.0339
# Epoch 68/100
# 23/23 [==============================] - 1s 31ms/step - loss: 0.0011 - mean_absolute_error: 0.0251 - val_loss: 0.0039 - val_mean_absolute_error: 0.0439
# Epoch 69/100
# 23/23 [==============================] - 1s 36ms/step - loss: 0.0010 - mean_absolute_error: 0.0243 - val_loss: 0.0028 - val_mean_absolute_error: 0.0363
# Epoch 70/100
# 23/23 [==============================] - 1s 32ms/step - loss: 0.0011 - mean_absolute_error: 0.0242 - val_loss: 0.0024 - val_mean_absolute_error: 0.0331
# Epoch 71/100
# 23/23 [==============================] - 1s 32ms/step - loss: 9.8184e-04 - mean_absolute_error: 0.0235 - val_loss: 0.0039 - val_mean_absolute_error: 0.0442
# Epoch 72/100
# 23/23 [==============================] - 1s 36ms/step - loss: 0.0010 - mean_absolute_error: 0.0238 - val_loss: 0.0027 - val_mean_absolute_error: 0.0355
# Epoch 73/100
# 23/23 [==============================] - 1s 36ms/step - loss: 9.4602e-04 - mean_absolute_error: 0.0229 - val_loss: 0.0027 - val_mean_absolute_error: 0.0346
# Epoch 74/100
# 23/23 [==============================] - 1s 33ms/step - loss: 9.4071e-04 - mean_absolute_error: 0.0228 - val_loss: 0.0027 - val_mean_absolute_error: 0.0349
# Epoch 75/100
# 23/23 [==============================] - 1s 35ms/step - loss: 9.0160e-04 - mean_absolute_error: 0.0221 - val_loss: 0.0029 - val_mean_absolute_error: 0.0376
# Epoch 76/100
# 23/23 [==============================] - 1s 32ms/step - loss: 9.0549e-04 - mean_absolute_error: 0.0220 - val_loss: 0.0023 - val_mean_absolute_error: 0.0328
# Epoch 77/100
# 23/23 [==============================] - 1s 40ms/step - loss: 8.6236e-04 - mean_absolute_error: 0.0218 - val_loss: 0.0039 - val_mean_absolute_error: 0.0466
# Epoch 78/100
# 23/23 [==============================] - 1s 32ms/step - loss: 8.7269e-04 - mean_absolute_error: 0.0217 - val_loss: 0.0037 - val_mean_absolute_error: 0.0452
# Epoch 79/100
# 23/23 [==============================] - 1s 33ms/step - loss: 8.7473e-04 - mean_absolute_error: 0.0215 - val_loss: 0.0029 - val_mean_absolute_error: 0.0368
# Epoch 80/100
# 23/23 [==============================] - 1s 30ms/step - loss: 8.6406e-04 - mean_absolute_error: 0.0214 - val_loss: 0.0030 - val_mean_absolute_error: 0.0404
# Epoch 81/100
# 23/23 [==============================] - 1s 39ms/step - loss: 9.0330e-04 - mean_absolute_error: 0.0221 - val_loss: 0.0058 - val_mean_absolute_error: 0.0609
# Epoch 82/100
# 23/23 [==============================] - 1s 34ms/step - loss: 9.6592e-04 - mean_absolute_error: 0.0231 - val_loss: 0.0027 - val_mean_absolute_error: 0.0354
# Epoch 83/100
# 23/23 [==============================] - 1s 35ms/step - loss: 8.7642e-04 - mean_absolute_error: 0.0221 - val_loss: 0.0026 - val_mean_absolute_error: 0.0341
# Epoch 84/100
# 23/23 [==============================] - 1s 38ms/step - loss: 8.0025e-04 - mean_absolute_error: 0.0207 - val_loss: 0.0023 - val_mean_absolute_error: 0.0323
# Epoch 85/100
# 23/23 [==============================] - 1s 33ms/step - loss: 7.8567e-04 - mean_absolute_error: 0.0207 - val_loss: 0.0033 - val_mean_absolute_error: 0.0399
# Epoch 86/100
# 23/23 [==============================] - 1s 35ms/step - loss: 8.3735e-04 - mean_absolute_error: 0.0212 - val_loss: 0.0029 - val_mean_absolute_error: 0.0360
# Epoch 87/100
# 23/23 [==============================] - 1s 33ms/step - loss: 7.5332e-04 - mean_absolute_error: 0.0201 - val_loss: 0.0020 - val_mean_absolute_error: 0.0299
# Epoch 88/100
# 23/23 [==============================] - 1s 34ms/step - loss: 7.5799e-04 - mean_absolute_error: 0.0206 - val_loss: 0.0037 - val_mean_absolute_error: 0.0455
# Epoch 89/100
# 23/23 [==============================] - 1s 34ms/step - loss: 7.8547e-04 - mean_absolute_error: 0.0209 - val_loss: 0.0023 - val_mean_absolute_error: 0.0322
# Epoch 90/100
# 23/23 [==============================] - 1s 35ms/step - loss: 7.6869e-04 - mean_absolute_error: 0.0204 - val_loss: 0.0022 - val_mean_absolute_error: 0.0316
# Epoch 91/100
# 23/23 [==============================] - 1s 31ms/step - loss: 7.6005e-04 - mean_absolute_error: 0.0201 - val_loss: 0.0028 - val_mean_absolute_error: 0.0358
# Epoch 92/100
# 23/23 [==============================] - 1s 36ms/step - loss: 7.8898e-04 - mean_absolute_error: 0.0200 - val_loss: 0.0029 - val_mean_absolute_error: 0.0379
# Epoch 93/100
# 23/23 [==============================] - 1s 34ms/step - loss: 7.1874e-04 - mean_absolute_error: 0.0195 - val_loss: 0.0035 - val_mean_absolute_error: 0.0427
# Epoch 94/100
# 23/23 [==============================] - 1s 35ms/step - loss: 7.7142e-04 - mean_absolute_error: 0.0203 - val_loss: 0.0028 - val_mean_absolute_error: 0.0362
# Epoch 95/100
# 23/23 [==============================] - 1s 33ms/step - loss: 7.0970e-04 - mean_absolute_error: 0.0192 - val_loss: 0.0019 - val_mean_absolute_error: 0.0296
# Epoch 96/100
# 23/23 [==============================] - 1s 38ms/step - loss: 8.0611e-04 - mean_absolute_error: 0.0208 - val_loss: 0.0021 - val_mean_absolute_error: 0.0308
# Epoch 97/100
# 23/23 [==============================] - 1s 33ms/step - loss: 7.1472e-04 - mean_absolute_error: 0.0195 - val_loss: 0.0038 - val_mean_absolute_error: 0.0473
# Epoch 98/100
# 23/23 [==============================] - 1s 32ms/step - loss: 8.2587e-04 - mean_absolute_error: 0.0211 - val_loss: 0.0027 - val_mean_absolute_error: 0.0349
# Epoch 99/100
# 23/23 [==============================] - 1s 32ms/step - loss: 7.8075e-04 - mean_absolute_error: 0.0205 - val_loss: 0.0022 - val_mean_absolute_error: 0.0315
# Epoch 100/100
# 23/23 [==============================] - 1s 34ms/step - loss: 7.8053e-04 - mean_absolute_error: 0.0199 - val_loss: 0.0019 - val_mean_absolute_error: 0.0286

# %%
test_predicted = model.predict(test_seq)
test_predicted[:5]
# Out:
# 7/7 [==============================] - 1s 10ms/step
# array([[0.6974918 , 0.6913324 ],
#        [0.6343426 , 0.6302424 ],
#        [0.5999927 , 0.6008749 ],
#        [0.59595776, 0.5996153 ],
#        [0.6117756 , 0.6152566 ]], dtype=float32)

# %%
test_inverse_predicted = MMS.inverse_transform(test_predicted)
test_inverse_predicted[:5]
# Out:
# array([[553.67114, 550.3789 ],
#        [524.7216 , 522.41125],
#        [508.9746 , 508.96655],
#        [507.1249 , 508.38986],
#        [514.3762 , 515.5506 ]], dtype=float32)

# %%
df1 = pd.concat([df.iloc[-202:].copy(),
pd.DataFrame(test_inverse_predicted,columns=['open_predicted','close_predicted'],index=df.iloc[-202:].index)], axis=1)

# %%
df1[['Open','Close']] = MMS.inverse_transform(df1[['Open','Close']])
df1.head()
# Out:
#                   Open       Close  open_predicted  close_predicted
# Date
# 2021-04-21  508.000000  508.899994      553.671143       550.378906
# 2021-04-22  513.820007  508.779999      524.721619       522.411255
# 2021-04-23  509.010010  505.549988      508.974609       508.966553
# 2021-04-26  506.760010  510.299988      507.124908       508.389862
# 2021-04-27  512.619995  505.549988      514.376221       515.550598

# %%
df1[['Open','open_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for open price',size=15)
plt.show()

# %%
df1[['Close','close_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for close price',size=15)
plt.show()

# %%
df1
# Out:
#                   Open       Close  open_predicted  close_predicted
# Date
# 2021-04-21  508.000000  508.899994      553.671143       550.378906
# 2021-04-22  513.820007  508.779999      524.721619       522.411255
# 2021-04-23  509.010010  505.549988      508.974609       508.966553
# 2021-04-26  506.760010  510.299988      507.124908       508.389862
# 2021-04-27  512.619995  505.549988      514.376221       515.550598
# ...                ...         ...             ...              ...
# 2022-01-31  401.970001  427.140015      407.745422       412.672058
# 2022-02-01  432.959991  457.130005      429.028503       431.714417
# 2022-02-02  448.250000  429.480011      454.616333       455.689636
# 2022-02-03  421.440002  405.600006      458.048706       457.876038
# 2022-02-04  407.309998  410.170013      437.033478       437.109253
#
# [202 rows x 4 columns]

# %%
df2 = pd.concat([df1,pd.DataFrame(columns=df1.columns,index=pd.date_range(start=df1.index[-1], periods=11, freq='D'))],axis=0)
df2['2022-02-03':'2022-02-21']
# Out:
#                   Open       Close  open_predicted  close_predicted
# 2022-02-03  421.440002  405.600006      458.048706       457.876038
# 2022-02-04  407.309998  410.170013      437.033478       437.109253
# 2022-02-04         NaN         NaN             NaN              NaN
# 2022-02-05         NaN         NaN             NaN              NaN
# 2022-02-06         NaN         NaN             NaN              NaN
# 2022-02-07         NaN         NaN             NaN              NaN
# 2022-02-08         NaN         NaN             NaN              NaN
# 2022-02-09         NaN         NaN             NaN              NaN
# 2022-02-10         NaN         NaN             NaN              NaN
# 2022-02-11         NaN         NaN             NaN              NaN
# 2022-02-12         NaN         NaN             NaN              NaN
# 2022-02-13         NaN         NaN             NaN              NaN
# 2022-02-14         NaN         NaN             NaN              NaN

# %%
forthcoming_prediction = pd.DataFrame(columns=['open','close'],index=df1.index)
forthcoming_prediction.index=pd.to_datetime(forthcoming_prediction.index)
curr_seq = test_seq[-1:]

for i in range(-10,0):
  up_pred = model.predict(curr_seq)
  forthcoming_prediction.iloc[i] = up_pred
  curr_seq = np.append(curr_seq[0][1:],up_pred,axis=0)
  curr_seq = curr_seq.reshape(test_seq[-1:].shape)
# Out:
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 34ms/step

# %%
forthcoming_prediction[['open','close']] = MMS.inverse_transform(forthcoming_prediction[['open','close']])
# plotting forthcoming Open price on date index
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df1.loc['2022-01-24':,'Open'],label='Current Open Price')
ax.plot(forthcoming_prediction.loc['2022-01-24':,'open'],label='Upcoming Open Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('forthcoming Open price prediction',size=15)
ax.legend()
fig.show()

# %%
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df1.loc['2022-01-24':,'Close'],label='Current close Price')
ax.plot(forthcoming_prediction.loc['2022-01-24':,'close'],label='Upcoming close Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('forthcoming close price prediction',size=15)
ax.legend()
fig.show()
